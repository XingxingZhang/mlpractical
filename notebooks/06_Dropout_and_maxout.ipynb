# %% [markdown]
# # Dropout and maxout
# In this lab we will explore the methods of [dropout](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf), a regularisation method which stochastically drops out activations from the model during training, and [maxout](http://www.jmlr.org/proceedings/papers/v28/goodfellow13.pdf), another non-linear transformation that can be used in multiple layer models. This is based on material covered in the [fifth lecture slides](http://www.inf.ed.ac.uk/teaching/courses/mlp/2016/mlp05-hid.pdf).

# %% [markdown]
# ## Exercise 1: Implementing a dropout layer
#
# During training the forward propagation through a dropout layer produces outputs where a subset of the input dimensions are set to zero ('dropped out'). The dimensions to be dropped out are randomly sampled for each new batch, with each dimension having a probability $p$ of being included and the inclusion (or not) of each dimension independent of all the others. If the inputs to a dropout layer are $D$ dimensional vectors then we can represent the dropout operation by an elementwise multiplication by a $D$ dimensional *binary mask* vector $\boldsymbol{m} = \left[m_1 ~ m_2 ~\dots~ m_D\right]^{\rm T}$ where $m_d \sim \text{Bernoulli}(p) ~~\forall d \in \lbrace 1 \dots D\rbrace$.
#
# As a first step implement a `random_binary_mask` function in the cell below to generate a binary mask array of a specified shape, where each value in the outputted array is either a one with probablity `prob_1` or zero with probability `1 - prob_1` and all values are sampled independently.

# %%
import numpy as np

def random_binary_mask(prob_1, shape, rng):
    """Generates a random binary mask array of a given shape.
    
    Each value in the outputted array should be an indepedently sampled
    binary value i.e in {0, 1} with the probability of each value
    being 1 being equal to `prob_1`.
    
    Args:
        prob_1: Scalar value in [0, 1] specifying probability each
            entry in output array is equal to one.
        shape: Shape of returned mask array.
        rng (RandomState): Seeded random number generator object.
    
    Returns:
        Random binary mask array of specified shape.
    """
    
    return rng.binomial(1, prob_1, shape).astype('float32')

# %% [markdown]
# Test your `random_binary_mask` function using the cell below (if your implementation is incorrect you will get an `AssertionError` - look at what the assert statement is checking for a clue as to what is wrong).

# %%
import numpy as np
test_shapes = [(1, 1000), (10, 10, 10)]
test_probs = [0.1, 0.5, 0.7]
for i in range(10):
    for shape in test_shapes:
        for prob in test_probs:
            output = random_binary_mask(prob, shape, np.random)
            # Check generating correct shape output
            assert output.shape == shape
            # Check all outputs are binary values
            assert np.all((output == 1.) | (output == 0.))
            # Check proportion equal to one plausible
            # This will be noisy so there is a chance this will error
            # even for a correct implementation
            assert np.abs(output.mean() - prob) < 0.1

# %% [markdown]
# Given a randomly sampled binary mask $\boldsymbol{m}$, the outputs $\lbrace \boldsymbol{y}^{(b)} \rbrace_{b=1}^B$ of the stochastic forward propagation through a dropout layer given a batch of inputs $\lbrace \boldsymbol{x}^{(b)} \rbrace_{b=1}^B$ can be calculated by simply performing an elementwise multiplication of the inputs with the mask
#
# \begin{equation}
#   y^{(b)}_d = m_k x^{(b)}_d \qquad \forall d \in \lbrace 1 \dots D \rbrace
# \end{equation}
#
# The corresponding partial derivatives required for implementing back-propagation through a dropout layer are
#
# \begin{equation}
#   \frac{\partial y^{(b)}_k}{\partial x^{(b)}_d} =
#   \begin{cases}
#       m_k & \quad k = d \\
#       0   & \quad k \neq d
#   \end{cases}
#   \qquad \forall k,\,d \in \lbrace 1 \dots D \rbrace
# \end{equation}
#
# As discussed in the lecture slides, when using a model trained with dropout at test time dimensions are no longer stochastically dropped out and instead all activations are deterministically fed forward through the model. So that the expected (mean) outputs of each layer are the same at test and training we scale the forward propagated inputs during testing by $p$ the probability of each dimension being included in the output. If we denote the deterministically forward-propagated batch of outputs of a dropout layer at test time as $\lbrace \boldsymbol{z}^{(b)} \rbrace_{b=1}^B$ then we have
#
# \begin{equation}
#   z^{(b)}_d =
#   \mathbb{E}\left[ y^{(b)}_d \right] =
#   \sum_{m_d \in \lbrace 0,1 \rbrace} \left( \mathbb{P}\left[\mathrm{m}_d = m_d\right] m_d x^{(b)}_d \right) =
#   (p) (1) x^{(b)}_d  + (1-p) (0) x^{(b)}_d =
#   p x^{(b)}_d  \qquad \forall d \in \lbrace 1 \dots D \rbrace
# \end{equation}
#
# To allow switching between this stochastic training time behaviour and deterministic test time behaviour, a new abstract `StochasticLayer` class has been defined in the `mlp.layers` module. This acts similarly to the layer objects we have already encountered other than adding an extra boolean argument `stochastic` to the `fprop` method interface. When `stochastic = True` (the default) a stochastic forward propagation should be caculated, for dropout this corresponding to $\boldsymbol{x}^{(b)} \to \boldsymbol{y}^{(b)}$ above. When `stochastic = False` a deterministic forward-propagation corresponding to the expected output of the stochastic forward-propagation should be calculated, for dropout this corresponding to $\boldsymbol{x}^{(b)} \to \boldsymbol{z}^{(b)}$ above.
#
# Using the skeleton `DropoutLayer` class definition below, implement the `fprop` and `bprop` methods. You may wish to store the binary mask used in the forward propagation as an attribute of the class for use in back-propagation - it is fine to assume that the `fprop` and `bprop` will always be called in sync.

# %%
from mlp.layers import StochasticLayer

class DropoutLayer(StochasticLayer):
    """Layer which stochastically drops input dimensions in its output."""
    
    def __init__(self, rng=None, incl_prob=0.5):
        """Construct a new dropout layer.
        
        Args:
            rng (RandomState): Seeded random number generator.
            incl_prob: Scalar value in (0, 1] specifying the probability of
                each input dimension being included in the output.
        """
        super(DropoutLayer, self).__init__(rng)
        assert incl_prob > 0. and incl_prob <= 1.
        self.incl_prob = incl_prob
        
    def fprop(self, inputs, stochastic=True):
        """Forward propagates activations through the layer transformation.

        Args:
            inputs: Array of layer inputs of shape (batch_size, input_dim).
            stochastic: Flag allowing different deterministic
                forward-propagation mode in addition to default stochastic
                forward-propagation e.g. for use at test time. If False
                a deterministic forward-propagation transformation
                corresponding to the expected output of the stochastic
                forward-propagation is applied.

        Returns:
            outputs: Array of layer outputs of shape (batch_size, output_dim).
        """
        
        if stochastic:
            self.mask = rng.binomial(1, self.incl_prob, inputs.shape).astype('float')
            return inputs * self.mask
        else:
            return inputs * self.incl_prob
    
    def bprop(self, inputs, outputs, grads_wrt_outputs):
        """Back propagates gradients through a layer.

        Given gradients with respect to the outputs of the layer calculates the
        gradients with respect to the layer inputs. This should correspond to
        default stochastic forward-propagation.

        Args:
            inputs: Array of layer inputs of shape (batch_size, input_dim).
            outputs: Array of layer outputs calculated in forward pass of
                shape (batch_size, output_dim).
            grads_wrt_outputs: Array of gradients with respect to the layer
                outputs of shape (batch_size, output_dim).

        Returns:
            Array of gradients with respect to the layer inputs of shape
            (batch_size, input_dim).
        """
        return grads_wrt_outputs * self.mask

    def __repr__(self):
        return 'DropoutLayer(incl_prob={0:.1f})'.format(self.incl_prob)

# %% [markdown]
# Test your implementation by running the cell below (if your implementation is incorrect you will get an `AssertionError` - look at what the assert statement is checking for a clue as to what is wrong).

# %%
seed = 31102016 
rng = np.random.RandomState(seed)
test_incl_probs = [0.1, 0.5, 0.7]
input_shape = (5, 10)
for incl_prob in test_incl_probs:
    layer = DropoutLayer(rng, incl_prob)
    inputs = rng.normal(size=input_shape)
    grads_wrt_outputs = rng.normal(size=input_shape)
    for t in range(100):
        outputs = layer.fprop(inputs, stochastic=True)
        # Check outputted array correct shape
        assert outputs.shape == inputs.shape
        # Check all outputs are either equal to inputs or zero
        assert np.all((outputs == inputs) | (outputs == 0))
        grads_wrt_inputs = layer.bprop(inputs, outputs, grads_wrt_outputs)
        # Check back-propagated gradients only non-zero for non-zero outputs
        assert np.all((outputs != 0) == (grads_wrt_inputs != 0))
        assert np.all(grads_wrt_outputs[outputs != 0] == grads_wrt_inputs[outputs != 0])
    det_outputs = layer.fprop(inputs, stochastic=False)
    # Check deterministic fprop outputs are correct shape
    assert det_outputs.shape == inputs.shape
    # Check deterministic fprop outputs scaled correctly
    assert np.allclose(det_outputs, incl_prob * inputs)

# %% [markdown]
# ### Optional extension
#
# Above we assumed the same dropout mask was applied to each input in a batch, as specified in the lecture slides. In practice sometimes a different mask is sampled for each input. As an extension you could try implementing this per-input form of dropout either by defining a new layer or adding an extra argument to the constructor of the above layer which allows you to switch between the two forms.

# %% [markdown]
# # Baseline

# %%
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider
from mlp.models import MultipleLayerModel
from mlp.layers import ReluLayer, AffineLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.initialisers import GlorotUniformInit, ConstantInit
from mlp.learning_rules import MomentumLearningRule
from mlp.optimisers import Optimiser
import matplotlib.pyplot as plt
# %matplotlib inline

# Seed a random number generator
seed = 31102016 
rng = np.random.RandomState(seed)

# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=50, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=50, rng=rng)
# Out:
# /afs/inf.ed.ac.uk/user/s12/s1270921/virtualenvs/py27/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
def getDatasetSize(train_data):
    cnt = 0
    for x, y in train_data:
        cnt += x.shape[0]
    
    return cnt

print getDatasetSize(train_data)
print getDatasetSize(valid_data)
# Out:
# 50000
# 10000

# %%
# Probability of input being included in output in dropout layer
incl_prob = 0.5

input_dim, output_dim, hidden_dim = 784, 10, 125

# Use Glorot initialisation scheme for weights and zero biases
weights_init = GlorotUniformInit(rng=rng, gain=2.**0.5)
biases_init = ConstantInit(0.)

# Create three affine layer model with rectified linear non-linearities
# and dropout layers before every affine layer
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError()

# Use a momentum learning rule - you could use an adaptive learning rule
# implemented for the coursework here instead
learning_rule = MomentumLearningRule(0.02, 0.9)

# Monitor classification accuracy during training
data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

optimiser = Optimiser(
    model, error, learning_rule, train_data, valid_data, data_monitors)

num_epochs = 100
stats_interval = 5

stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

# Plot the change in the validation and training set error over training.
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)', 'error(valid)']:
    ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
              stats[1:, keys[k]], label=k)
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')

# Plot the change in the validation and training set accuracy over training.
fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['acc(train)', 'acc(valid)']:
    ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
              stats[1:, keys[k]], label=k)
ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
# Out:
# Epoch 0:
#   error(train)=2.43e+00, acc(train)=1.06e-01, error(valid)=2.42e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 5: 1.34s to complete
#   error(train)=4.40e-02, acc(train)=9.86e-01, error(valid)=1.01e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 10: 1.38s to complete
#   error(train)=1.22e-02, acc(train)=9.96e-01, error(valid)=9.53e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 15: 2.24s to complete
#   error(train)=1.17e-03, acc(train)=1.00e+00, error(valid)=8.95e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 20: 1.40s to complete
#   error(train)=4.54e-04, acc(train)=1.00e+00, error(valid)=9.40e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 25: 1.41s to complete
#   error(train)=3.15e-04, acc(train)=1.00e+00, error(valid)=9.73e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 30: 1.51s to complete
#   error(train)=2.48e-04, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 35: 1.40s to complete
#   error(train)=2.01e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 40: 1.40s to complete
#   error(train)=1.70e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 45: 2.82s to complete
#   error(train)=1.47e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 50: 1.39s to complete
#   error(train)=1.29e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 55: 3.54s to complete
#   error(train)=1.16e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 60: 2.87s to complete
#   error(train)=1.04e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 65: 2.22s to complete
#   error(train)=9.41e-05, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 70: 2.18s to complete
#   error(train)=8.63e-05, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 75: 1.40s to complete
#   error(train)=7.94e-05, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 80: 3.74s to complete
#   error(train)=7.36e-05, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 85: 1.40s to complete
#   error(train)=6.87e-05, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 90: 1.40s to complete
#   error(train)=6.41e-05, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 95: 1.70s to complete
#   error(train)=6.04e-05, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 100: 2.15s to complete
#   error(train)=5.66e-05, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00

# %% [markdown]
# ## Exercise 2: Training with dropout

# %% [markdown]
# Experiment with training models with dropout layers to classify MNIST digits. Code has been provided below as a starting point for setting up the model objects though feel free to use any additional adaptive learning rules or learning rule schedulers you wrote during the coursework instead. You may also wish to change the model architecture to use a larger model with more parameters in which the regularisation provided by dropout is likely to have a more pronounced effect. You will probably also find that models with dropout generally need to be trained over more epochs than those without (can you suggest why this might be?).
#
# You should training with a few different `incl_prob` settings for the dropout layers and try to establish how the values chosen affect the training performance. You may wish to experiment with using a different dropout probability at the input than for the intermediate layers (why?).
#
# You may wish to start reading through and implementing exercise 3 while waiting for training runs to complete.

# %%
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider
from mlp.models import MultipleLayerModel
from mlp.layers import ReluLayer, AffineLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.initialisers import GlorotUniformInit, ConstantInit
from mlp.learning_rules import MomentumLearningRule
from mlp.optimisers import Optimiser
import matplotlib.pyplot as plt
# %matplotlib inline

# Seed a random number generator
seed = 31102016 
rng = np.random.RandomState(seed)

# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=50, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=50, rng=rng)
# Out:
# /afs/inf.ed.ac.uk/user/s12/s1270921/virtualenvs/py27/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# Probability of input being included in output in dropout layer
incl_prob = 0.5

input_dim, output_dim, hidden_dim = 784, 10, 125

# Use Glorot initialisation scheme for weights and zero biases
weights_init = GlorotUniformInit(rng=rng, gain=2.**0.5)
biases_init = ConstantInit(0.)

# Create three affine layer model with rectified linear non-linearities
# and dropout layers before every affine layer
model = MultipleLayerModel([
    DropoutLayer(rng, incl_prob),
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError()

# Use a momentum learning rule - you could use an adaptive learning rule
# implemented for the coursework here instead
learning_rule = MomentumLearningRule(0.02, 0.9)

# Monitor classification accuracy during training
data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

optimiser = Optimiser(
    model, error, learning_rule, train_data, valid_data, data_monitors)

num_epochs = 100
stats_interval = 5

stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

# Plot the change in the validation and training set error over training.
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)', 'error(valid)']:
    ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
              stats[1:, keys[k]], label=k)
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')

# Plot the change in the validation and training set accuracy over training.
fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['acc(train)', 'acc(valid)']:
    ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
              stats[1:, keys[k]], label=k)
ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
# Out:
# Epoch 0:
#   error(train)=2.33e+00, acc(train)=9.90e-02, error(valid)=2.32e+00, acc(valid)=9.43e-02, params_penalty=0.00e+00
# Epoch 5: 3.14s to complete
#   error(train)=4.33e-01, acc(train)=8.70e-01, error(valid)=4.04e-01, acc(valid)=8.79e-01, params_penalty=0.00e+00
# Epoch 10: 3.19s to complete
#   error(train)=3.54e-01, acc(train)=8.92e-01, error(valid)=3.39e-01, acc(valid)=9.02e-01, params_penalty=0.00e+00
# Epoch 15: 3.22s to complete
#   error(train)=3.24e-01, acc(train)=9.03e-01, error(valid)=3.23e-01, acc(valid)=9.03e-01, params_penalty=0.00e+00
# Epoch 20: 3.25s to complete
#   error(train)=3.00e-01, acc(train)=9.09e-01, error(valid)=2.89e-01, acc(valid)=9.16e-01, params_penalty=0.00e+00
# Epoch 25: 3.22s to complete
#   error(train)=2.92e-01, acc(train)=9.11e-01, error(valid)=2.77e-01, acc(valid)=9.16e-01, params_penalty=0.00e+00
# Epoch 30: 5.18s to complete
#   error(train)=2.79e-01, acc(train)=9.16e-01, error(valid)=2.60e-01, acc(valid)=9.21e-01, params_penalty=0.00e+00
# Epoch 35: 3.29s to complete
#   error(train)=2.71e-01, acc(train)=9.18e-01, error(valid)=2.79e-01, acc(valid)=9.16e-01, params_penalty=0.00e+00
# Epoch 40: 4.35s to complete
#   error(train)=2.71e-01, acc(train)=9.18e-01, error(valid)=2.68e-01, acc(valid)=9.19e-01, params_penalty=0.00e+00
# Epoch 45: 4.54s to complete
#   error(train)=2.64e-01, acc(train)=9.20e-01, error(valid)=2.68e-01, acc(valid)=9.21e-01, params_penalty=0.00e+00
# Epoch 50: 3.27s to complete
#   error(train)=2.63e-01, acc(train)=9.21e-01, error(valid)=2.52e-01, acc(valid)=9.27e-01, params_penalty=0.00e+00
# Epoch 55: 3.84s to complete
#   error(train)=2.56e-01, acc(train)=9.23e-01, error(valid)=2.55e-01, acc(valid)=9.27e-01, params_penalty=0.00e+00
# Epoch 60: 3.57s to complete
#   error(train)=2.53e-01, acc(train)=9.25e-01, error(valid)=2.49e-01, acc(valid)=9.26e-01, params_penalty=0.00e+00
# Epoch 65: 3.29s to complete
#   error(train)=2.52e-01, acc(train)=9.25e-01, error(valid)=2.56e-01, acc(valid)=9.24e-01, params_penalty=0.00e+00
# Epoch 70: 4.68s to complete
#   error(train)=2.49e-01, acc(train)=9.24e-01, error(valid)=2.45e-01, acc(valid)=9.28e-01, params_penalty=0.00e+00
# Epoch 75: 4.01s to complete
#   error(train)=2.43e-01, acc(train)=9.26e-01, error(valid)=2.43e-01, acc(valid)=9.28e-01, params_penalty=0.00e+00
# Epoch 80: 3.43s to complete
#   error(train)=2.41e-01, acc(train)=9.26e-01, error(valid)=2.53e-01, acc(valid)=9.25e-01, params_penalty=0.00e+00
# Epoch 85: 3.62s to complete
#   error(train)=2.41e-01, acc(train)=9.27e-01, error(valid)=2.47e-01, acc(valid)=9.25e-01, params_penalty=0.00e+00
# Epoch 90: 3.30s to complete
#   error(train)=2.44e-01, acc(train)=9.27e-01, error(valid)=2.47e-01, acc(valid)=9.33e-01, params_penalty=0.00e+00
# Epoch 95: 3.31s to complete
#   error(train)=2.37e-01, acc(train)=9.27e-01, error(valid)=2.33e-01, acc(valid)=9.30e-01, params_penalty=0.00e+00
# Epoch 100: 3.37s to complete
#   error(train)=2.45e-01, acc(train)=9.26e-01, error(valid)=2.40e-01, acc(valid)=9.28e-01, params_penalty=0.00e+00

# %%
# Probability of input being included in output in dropout layer
incl_prob = 0.5

input_dim, output_dim, hidden_dim = 784, 10, 125

# Use Glorot initialisation scheme for weights and zero biases
weights_init = GlorotUniformInit(rng=rng, gain=2.**0.5)
biases_init = ConstantInit(0.)

# Create three affine layer model with rectified linear non-linearities
# and dropout layers before every affine layer
model = MultipleLayerModel([
    DropoutLayer(rng, incl_prob),
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    DropoutLayer(rng, incl_prob),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError()

# Use a momentum learning rule - you could use an adaptive learning rule
# implemented for the coursework here instead
learning_rule = MomentumLearningRule(0.02, 0.9)

# Monitor classification accuracy during training
data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

optimiser = Optimiser(
    model, error, learning_rule, train_data, valid_data, data_monitors,use_stochastic_eval=False)

num_epochs = 100
stats_interval = 5

stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

# Plot the change in the validation and training set error over training.
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)', 'error(valid)']:
    ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
              stats[1:, keys[k]], label=k)
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')

# Plot the change in the validation and training set accuracy over training.
fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['acc(train)', 'acc(valid)']:
    ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
              stats[1:, keys[k]], label=k)
ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
# Out:
# Epoch 0:
#   error(train)=2.31e+00, acc(train)=1.03e-01, error(valid)=2.31e+00, acc(valid)=1.00e-01, params_penalty=0.00e+00
# Epoch 5: 3.06s to complete
#   error(train)=1.83e-01, acc(train)=9.47e-01, error(valid)=1.64e-01, acc(valid)=9.55e-01, params_penalty=0.00e+00
# Epoch 10: 5.20s to complete
#   error(train)=1.40e-01, acc(train)=9.60e-01, error(valid)=1.31e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# Epoch 15: 3.35s to complete
#   error(train)=1.22e-01, acc(train)=9.63e-01, error(valid)=1.15e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 20: 3.85s to complete
#   error(train)=1.09e-01, acc(train)=9.68e-01, error(valid)=1.05e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 25: 3.43s to complete
#   error(train)=1.05e-01, acc(train)=9.68e-01, error(valid)=1.06e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 30: 3.24s to complete
#   error(train)=9.79e-02, acc(train)=9.70e-01, error(valid)=1.00e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 35: 3.88s to complete
#   error(train)=9.31e-02, acc(train)=9.72e-01, error(valid)=9.92e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 3.60s to complete
#   error(train)=9.02e-02, acc(train)=9.73e-01, error(valid)=9.72e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 45: 4.07s to complete
#   error(train)=8.78e-02, acc(train)=9.74e-01, error(valid)=9.60e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 50: 3.26s to complete
#   error(train)=8.59e-02, acc(train)=9.74e-01, error(valid)=9.36e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 55: 4.38s to complete
#   error(train)=8.27e-02, acc(train)=9.76e-01, error(valid)=9.25e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 60: 3.27s to complete
#   error(train)=8.31e-02, acc(train)=9.75e-01, error(valid)=9.16e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 65: 3.24s to complete
#   error(train)=7.95e-02, acc(train)=9.76e-01, error(valid)=9.09e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 70: 8.67s to complete
#   error(train)=7.81e-02, acc(train)=9.76e-01, error(valid)=9.00e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 75: 4.17s to complete
#   error(train)=8.01e-02, acc(train)=9.76e-01, error(valid)=9.44e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 80: 4.23s to complete
#   error(train)=7.67e-02, acc(train)=9.77e-01, error(valid)=9.10e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 85: 4.95s to complete
#   error(train)=7.54e-02, acc(train)=9.77e-01, error(valid)=8.79e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 90: 3.35s to complete
#   error(train)=7.48e-02, acc(train)=9.78e-01, error(valid)=8.84e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 95: 3.35s to complete
#   error(train)=7.53e-02, acc(train)=9.77e-01, error(valid)=8.88e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 100: 5.37s to complete
#   error(train)=7.54e-02, acc(train)=9.77e-01, error(valid)=9.01e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00

# %% [markdown]
# # Dropout Tuning

# %%
def doDropoutExperiment(opts):
    
    # Seed a random number generator
    seed = 31102016 
    rng = np.random.RandomState(seed)

    # Set up a logger object to print info about the training run to stdout
    logger = logging.getLogger()
    logger.setLevel(logging.INFO)
    logger.handlers = [logging.StreamHandler()]

    # Create data provider objects for the MNIST data set
    train_data = MNISTDataProvider('train', batch_size=50, rng=rng)
    valid_data = MNISTDataProvider('valid', batch_size=50, rng=rng)
    
    # Probability of input being included in output in dropout layer
    incl_prob = opts['dropout']

    input_dim, output_dim, hidden_dim = 784, 10, 125

    # Use Glorot initialisation scheme for weights and zero biases
    weights_init = GlorotUniformInit(rng=rng, gain=2.**0.5)
    biases_init = ConstantInit(0.)

    # Create three affine layer model with rectified linear non-linearities
    # and dropout layers before every affine layer
    model = MultipleLayerModel([
        DropoutLayer(rng, incl_prob),
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        DropoutLayer(rng, incl_prob),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        DropoutLayer(rng, incl_prob),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

    # Multiclass classification therefore use cross-entropy + softmax error
    error = CrossEntropySoftmaxError()

    # Use a momentum learning rule - you could use an adaptive learning rule
    # implemented for the coursework here instead
    learning_rule = MomentumLearningRule(0.02, 0.9)

    # Monitor classification accuracy during training
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors,use_stochastic_eval=False)

    num_epochs = opts['epoch']
    stats_interval = 5

    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')
opts = dict(dropout = 0.8,
           epoch = 200)

doDropoutExperiment(opts)
    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')

# %%
opts = dict(dropout = 0.5,
           epoch = 200)

doDropoutExperiment(opts)
# Out:
# Epoch 0:
#   error(train)=2.29e+00, acc(train)=1.06e-01, error(valid)=2.29e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 5: 3.70s to complete
#   error(train)=1.93e-01, acc(train)=9.45e-01, error(valid)=1.78e-01, acc(valid)=9.49e-01, params_penalty=0.00e+00
# Epoch 10: 5.11s to complete
#   error(train)=1.42e-01, acc(train)=9.58e-01, error(valid)=1.37e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Epoch 15: 3.17s to complete
#   error(train)=1.25e-01, acc(train)=9.62e-01, error(valid)=1.25e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# Epoch 20: 3.17s to complete
#   error(train)=1.13e-01, acc(train)=9.67e-01, error(valid)=1.15e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Epoch 25: 4.98s to complete
#   error(train)=1.04e-01, acc(train)=9.69e-01, error(valid)=1.09e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 30: 5.18s to complete
#   error(train)=1.00e-01, acc(train)=9.70e-01, error(valid)=1.05e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 35: 3.17s to complete
#   error(train)=9.51e-02, acc(train)=9.72e-01, error(valid)=1.05e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 40: 3.53s to complete
#   error(train)=9.08e-02, acc(train)=9.73e-01, error(valid)=9.93e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 45: 3.25s to complete
#   error(train)=8.86e-02, acc(train)=9.74e-01, error(valid)=9.78e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 50: 3.26s to complete
#   error(train)=8.45e-02, acc(train)=9.75e-01, error(valid)=9.50e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 55: 4.13s to complete
#   error(train)=8.21e-02, acc(train)=9.75e-01, error(valid)=9.17e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 60: 3.27s to complete
#   error(train)=8.15e-02, acc(train)=9.75e-01, error(valid)=9.42e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 65: 3.28s to complete
#   error(train)=8.16e-02, acc(train)=9.76e-01, error(valid)=9.54e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 70: 5.09s to complete
#   error(train)=7.89e-02, acc(train)=9.76e-01, error(valid)=9.07e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 75: 3.41s to complete
#   error(train)=7.95e-02, acc(train)=9.77e-01, error(valid)=9.35e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 80: 6.47s to complete
#   error(train)=7.59e-02, acc(train)=9.77e-01, error(valid)=8.97e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 85: 4.08s to complete
#   error(train)=7.66e-02, acc(train)=9.77e-01, error(valid)=9.09e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 90: 3.74s to complete
#   error(train)=7.27e-02, acc(train)=9.78e-01, error(valid)=8.78e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 95: 3.27s to complete
#   error(train)=7.33e-02, acc(train)=9.78e-01, error(valid)=8.96e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 100: 3.24s to complete
#   error(train)=7.29e-02, acc(train)=9.78e-01, error(valid)=8.93e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 105: 3.25s to complete
#   error(train)=7.33e-02, acc(train)=9.78e-01, error(valid)=8.73e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 110: 6.17s to complete
#   error(train)=6.91e-02, acc(train)=9.80e-01, error(valid)=8.69e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 115: 4.11s to complete
#   error(train)=7.19e-02, acc(train)=9.79e-01, error(valid)=8.94e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 120: 3.44s to complete
#   error(train)=6.92e-02, acc(train)=9.79e-01, error(valid)=8.67e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 125: 4.71s to complete
#   error(train)=7.13e-02, acc(train)=9.79e-01, error(valid)=8.93e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 130: 3.61s to complete
#   error(train)=7.28e-02, acc(train)=9.78e-01, error(valid)=8.94e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 135: 5.05s to complete
#   error(train)=7.03e-02, acc(train)=9.79e-01, error(valid)=8.87e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 140: 4.34s to complete
#   error(train)=6.96e-02, acc(train)=9.79e-01, error(valid)=8.73e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 145: 4.26s to complete
#   error(train)=7.06e-02, acc(train)=9.79e-01, error(valid)=8.83e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 150: 4.37s to complete
#   error(train)=6.82e-02, acc(train)=9.80e-01, error(valid)=8.77e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 155: 3.58s to complete
#   error(train)=6.77e-02, acc(train)=9.80e-01, error(valid)=8.74e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 160: 5.23s to complete
#   error(train)=6.71e-02, acc(train)=9.80e-01, error(valid)=8.67e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 165: 5.70s to complete
#   error(train)=6.82e-02, acc(train)=9.80e-01, error(valid)=8.77e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 170: 3.83s to complete
#   error(train)=6.71e-02, acc(train)=9.80e-01, error(valid)=8.80e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 175: 3.71s to complete
#   error(train)=6.79e-02, acc(train)=9.80e-01, error(valid)=8.73e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 180: 3.78s to complete
#   error(train)=6.62e-02, acc(train)=9.80e-01, error(valid)=8.54e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 185: 3.85s to complete
#   error(train)=6.59e-02, acc(train)=9.80e-01, error(valid)=8.37e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 190: 3.82s to complete
#   error(train)=6.60e-02, acc(train)=9.80e-01, error(valid)=8.73e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 195: 3.86s to complete
#   error(train)=6.46e-02, acc(train)=9.81e-01, error(valid)=8.31e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 200: 3.78s to complete
#   error(train)=6.64e-02, acc(train)=9.80e-01, error(valid)=8.73e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00

# %%
opts = dict(dropout = 0.2,
           epoch = 200)

doDropoutExperiment(opts)
# Out:
# Epoch 0:
#   error(train)=2.30e+00, acc(train)=1.06e-01, error(valid)=2.30e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 5: 3.42s to complete
#   error(train)=1.07e+00, acc(train)=7.01e-01, error(valid)=1.04e+00, acc(valid)=7.14e-01, params_penalty=0.00e+00
# Epoch 10: 3.59s to complete
#   error(train)=8.07e-01, acc(train)=8.03e-01, error(valid)=7.76e-01, acc(valid)=8.21e-01, params_penalty=0.00e+00
# Epoch 15: 3.53s to complete
#   error(train)=6.97e-01, acc(train)=8.29e-01, error(valid)=6.61e-01, acc(valid)=8.48e-01, params_penalty=0.00e+00
# Epoch 20: 3.82s to complete
#   error(train)=6.37e-01, acc(train)=8.56e-01, error(valid)=5.98e-01, acc(valid)=8.72e-01, params_penalty=0.00e+00
# Epoch 25: 3.69s to complete
#   error(train)=6.10e-01, acc(train)=8.65e-01, error(valid)=5.72e-01, acc(valid)=8.81e-01, params_penalty=0.00e+00
# Epoch 30: 3.75s to complete
#   error(train)=5.72e-01, acc(train)=8.74e-01, error(valid)=5.35e-01, acc(valid)=8.89e-01, params_penalty=0.00e+00
# Epoch 35: 3.66s to complete
#   error(train)=5.51e-01, acc(train)=8.80e-01, error(valid)=5.12e-01, acc(valid)=8.95e-01, params_penalty=0.00e+00
# Epoch 40: 3.86s to complete
#   error(train)=5.29e-01, acc(train)=8.81e-01, error(valid)=4.91e-01, acc(valid)=8.97e-01, params_penalty=0.00e+00
# Epoch 45: 3.77s to complete
#   error(train)=5.16e-01, acc(train)=8.83e-01, error(valid)=4.78e-01, acc(valid)=8.96e-01, params_penalty=0.00e+00
# Epoch 50: 4.56s to complete
#   error(train)=5.05e-01, acc(train)=8.84e-01, error(valid)=4.67e-01, acc(valid)=8.98e-01, params_penalty=0.00e+00
# Epoch 55: 3.74s to complete
#   error(train)=5.01e-01, acc(train)=8.91e-01, error(valid)=4.64e-01, acc(valid)=9.05e-01, params_penalty=0.00e+00
# Epoch 60: 3.68s to complete
#   error(train)=4.92e-01, acc(train)=8.91e-01, error(valid)=4.55e-01, acc(valid)=9.05e-01, params_penalty=0.00e+00
# Epoch 65: 3.76s to complete
#   error(train)=4.92e-01, acc(train)=8.94e-01, error(valid)=4.56e-01, acc(valid)=9.08e-01, params_penalty=0.00e+00
# Epoch 70: 3.75s to complete
#   error(train)=4.85e-01, acc(train)=8.85e-01, error(valid)=4.49e-01, acc(valid)=8.97e-01, params_penalty=0.00e+00
# Epoch 75: 3.72s to complete
#   error(train)=4.76e-01, acc(train)=8.89e-01, error(valid)=4.41e-01, acc(valid)=9.03e-01, params_penalty=0.00e+00
# Epoch 80: 3.75s to complete
#   error(train)=4.62e-01, acc(train)=8.94e-01, error(valid)=4.27e-01, acc(valid)=9.05e-01, params_penalty=0.00e+00
# Epoch 85: 3.77s to complete
#   error(train)=4.68e-01, acc(train)=8.94e-01, error(valid)=4.33e-01, acc(valid)=9.05e-01, params_penalty=0.00e+00
# Epoch 90: 5.87s to complete
#   error(train)=4.64e-01, acc(train)=8.95e-01, error(valid)=4.30e-01, acc(valid)=9.08e-01, params_penalty=0.00e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-6974bb2f9c3c> in <module>()
#       2            epoch = 200)
#       3
# ----> 4 doDropoutExperiment(opts)
#
# <ipython-input-21-48b55e2a5cc9> in doDropoutExperiment(opts)
#      52     stats_interval = 5
#      53
# ---> 54     stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)
#      55
#      56     # Plot the change in the validation and training set error over training.
#
# /disk/scratch/Programming/MachineLearningPractical/mlp_private/mlpractical/mlp/optimisers.py in train(self, num_epochs, stats_interval)
#     143                 scheduler.update_learning_rule(self.learning_rule, epoch - 1)
#     144             start_time = time.time()
# --> 145             self.do_training_epoch()
#     146             epoch_time = time.time() - start_time
#     147             if epoch % stats_interval == 0:
#
# /disk/scratch/Programming/MachineLearningPractical/mlp_private/mlpractical/mlp/optimisers.py in do_training_epoch(self)
#      65             grads_wrt_params = self.model.grads_wrt_params(
#      66                 activations, grads_wrt_outputs)
# ---> 67             self.learning_rule.update_params(grads_wrt_params)
#      68
#      69     def eval_monitors(self, dataset, label):
#
# /disk/scratch/Programming/MachineLearningPractical/mlp_private/mlpractical/mlp/learning_rules.py in update_params(self, grads_wrt_params)
#     160             mom *= self.mom_coeff
#     161             mom -= self.learning_rate * grad
# --> 162             param += mom
#
# KeyboardInterrupt:

# %%
opts = dict(dropout = 0.8,
           epoch = 200)

doDropoutExperiment(opts)
# Out:
# Epoch 0:
#   error(train)=2.32e+00, acc(train)=1.06e-01, error(valid)=2.31e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 5: 3.55s to complete
#   error(train)=7.71e-02, acc(train)=9.76e-01, error(valid)=9.01e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 10: 5.22s to complete
#   error(train)=4.59e-02, acc(train)=9.86e-01, error(valid)=7.65e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 15: 3.56s to complete
#   error(train)=3.22e-02, acc(train)=9.90e-01, error(valid)=6.90e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 20: 3.24s to complete
#   error(train)=2.62e-02, acc(train)=9.93e-01, error(valid)=6.90e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 25: 3.42s to complete
#   error(train)=2.34e-02, acc(train)=9.93e-01, error(valid)=6.96e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 30: 3.31s to complete
#   error(train)=1.86e-02, acc(train)=9.95e-01, error(valid)=6.63e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 35: 4.51s to complete
#   error(train)=1.69e-02, acc(train)=9.95e-01, error(valid)=6.54e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 40: 3.91s to complete
#   error(train)=1.33e-02, acc(train)=9.96e-01, error(valid)=6.25e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 45: 4.40s to complete
#   error(train)=1.14e-02, acc(train)=9.97e-01, error(valid)=6.67e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 50: 4.49s to complete
#   error(train)=1.09e-02, acc(train)=9.97e-01, error(valid)=6.23e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 55: 4.15s to complete
#   error(train)=1.05e-02, acc(train)=9.97e-01, error(valid)=6.23e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 60: 5.38s to complete
#   error(train)=8.93e-03, acc(train)=9.98e-01, error(valid)=6.12e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 65: 3.11s to complete
#   error(train)=8.80e-03, acc(train)=9.98e-01, error(valid)=6.38e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 70: 3.10s to complete
#   error(train)=8.95e-03, acc(train)=9.98e-01, error(valid)=6.56e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 75: 3.07s to complete
#   error(train)=7.62e-03, acc(train)=9.98e-01, error(valid)=6.45e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 80: 3.10s to complete
#   error(train)=7.21e-03, acc(train)=9.98e-01, error(valid)=6.52e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 85: 7.32s to complete
#   error(train)=6.53e-03, acc(train)=9.98e-01, error(valid)=6.67e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 90: 3.06s to complete
#   error(train)=6.46e-03, acc(train)=9.99e-01, error(valid)=6.16e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 95: 4.17s to complete
#   error(train)=6.02e-03, acc(train)=9.99e-01, error(valid)=6.20e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 100: 3.13s to complete
#   error(train)=4.68e-03, acc(train)=9.99e-01, error(valid)=6.41e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 105: 3.11s to complete
#   error(train)=5.97e-03, acc(train)=9.99e-01, error(valid)=6.52e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 110: 3.03s to complete
#   error(train)=4.89e-03, acc(train)=9.99e-01, error(valid)=6.41e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 115: 3.27s to complete
#   error(train)=4.82e-03, acc(train)=9.99e-01, error(valid)=6.60e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 120: 3.82s to complete
#   error(train)=4.66e-03, acc(train)=9.99e-01, error(valid)=6.66e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 125: 5.52s to complete
#   error(train)=4.56e-03, acc(train)=9.99e-01, error(valid)=6.50e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 130: 4.04s to complete
#   error(train)=4.29e-03, acc(train)=9.99e-01, error(valid)=6.43e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 135: 3.03s to complete
#   error(train)=4.33e-03, acc(train)=9.99e-01, error(valid)=6.20e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 140: 3.08s to complete
#   error(train)=4.43e-03, acc(train)=9.99e-01, error(valid)=6.23e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 145: 3.09s to complete
#   error(train)=3.88e-03, acc(train)=9.99e-01, error(valid)=6.78e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 150: 3.68s to complete
#   error(train)=3.85e-03, acc(train)=9.99e-01, error(valid)=6.55e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 155: 3.83s to complete
#   error(train)=4.06e-03, acc(train)=9.99e-01, error(valid)=6.29e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 160: 3.62s to complete
#   error(train)=3.29e-03, acc(train)=9.99e-01, error(valid)=6.39e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 165: 3.89s to complete
#   error(train)=3.22e-03, acc(train)=9.99e-01, error(valid)=6.55e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 170: 3.76s to complete
#   error(train)=3.32e-03, acc(train)=9.99e-01, error(valid)=6.50e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 175: 3.97s to complete
#   error(train)=2.95e-03, acc(train)=1.00e+00, error(valid)=6.31e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 180: 3.75s to complete
#   error(train)=2.70e-03, acc(train)=1.00e+00, error(valid)=6.28e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 185: 3.13s to complete
#   error(train)=3.33e-03, acc(train)=9.99e-01, error(valid)=6.42e-02, acc(valid)=9.85e-01, params_penalty=0.00e+00
# Epoch 190: 3.12s to complete
#   error(train)=3.20e-03, acc(train)=9.99e-01, error(valid)=6.44e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 195: 3.16s to complete
#   error(train)=3.15e-03, acc(train)=9.99e-01, error(valid)=6.79e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 200: 3.09s to complete
#   error(train)=3.50e-03, acc(train)=9.99e-01, error(valid)=6.61e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00

# %%
opts = dict(dropout = 0.7,
           epoch = 200)

doDropoutExperiment(opts)
# Out:
# Epoch 0:
#   error(train)=2.30e+00, acc(train)=1.06e-01, error(valid)=2.30e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 5: 2.99s to complete
#   error(train)=1.07e-01, acc(train)=9.67e-01, error(valid)=1.12e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 10: 5.40s to complete
#   error(train)=6.85e-02, acc(train)=9.79e-01, error(valid)=8.56e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 15: 3.11s to complete
#   error(train)=5.65e-02, acc(train)=9.82e-01, error(valid)=7.73e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 20: 3.07s to complete
#   error(train)=4.79e-02, acc(train)=9.85e-01, error(valid)=7.55e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 25: 5.01s to complete
#   error(train)=4.02e-02, acc(train)=9.88e-01, error(valid)=6.95e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 30: 4.32s to complete
#   error(train)=3.66e-02, acc(train)=9.89e-01, error(valid)=7.20e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 35: 4.16s to complete
#   error(train)=3.40e-02, acc(train)=9.90e-01, error(valid)=6.80e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 40: 3.13s to complete
#   error(train)=3.20e-02, acc(train)=9.90e-01, error(valid)=6.80e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 45: 3.11s to complete
#   error(train)=2.88e-02, acc(train)=9.92e-01, error(valid)=6.61e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 50: 3.44s to complete
#   error(train)=2.66e-02, acc(train)=9.92e-01, error(valid)=6.46e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 55: 3.67s to complete
#   error(train)=2.54e-02, acc(train)=9.92e-01, error(valid)=6.43e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 60: 5.57s to complete
#   error(train)=2.59e-02, acc(train)=9.92e-01, error(valid)=6.68e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 65: 5.91s to complete
#   error(train)=2.30e-02, acc(train)=9.93e-01, error(valid)=6.21e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 70: 3.10s to complete
#   error(train)=2.46e-02, acc(train)=9.93e-01, error(valid)=6.38e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 75: 3.15s to complete
#   error(train)=2.29e-02, acc(train)=9.94e-01, error(valid)=6.21e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 80: 3.17s to complete
#   error(train)=2.09e-02, acc(train)=9.94e-01, error(valid)=6.39e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 85: 3.09s to complete
#   error(train)=1.96e-02, acc(train)=9.95e-01, error(valid)=6.17e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 90: 3.70s to complete
#   error(train)=2.01e-02, acc(train)=9.95e-01, error(valid)=6.39e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 95: 3.15s to complete
#   error(train)=1.92e-02, acc(train)=9.95e-01, error(valid)=6.32e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 100: 3.24s to complete
#   error(train)=1.97e-02, acc(train)=9.94e-01, error(valid)=6.33e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 105: 3.84s to complete
#   error(train)=1.98e-02, acc(train)=9.94e-01, error(valid)=6.29e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 110: 3.14s to complete
#   error(train)=1.75e-02, acc(train)=9.95e-01, error(valid)=6.21e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 115: 3.24s to complete
#   error(train)=1.70e-02, acc(train)=9.95e-01, error(valid)=6.35e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# Epoch 120: 3.73s to complete
#   error(train)=1.72e-02, acc(train)=9.95e-01, error(valid)=5.98e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 125: 3.45s to complete
#   error(train)=1.63e-02, acc(train)=9.96e-01, error(valid)=6.08e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 130: 3.19s to complete
#   error(train)=1.68e-02, acc(train)=9.96e-01, error(valid)=6.15e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 135: 3.16s to complete
#   error(train)=1.68e-02, acc(train)=9.95e-01, error(valid)=6.34e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 140: 3.21s to complete
#   error(train)=1.61e-02, acc(train)=9.96e-01, error(valid)=6.24e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 145: 4.71s to complete
#   error(train)=1.62e-02, acc(train)=9.95e-01, error(valid)=6.47e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 150: 3.56s to complete
#   error(train)=1.42e-02, acc(train)=9.96e-01, error(valid)=6.03e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 155: 5.23s to complete
#   error(train)=1.69e-02, acc(train)=9.96e-01, error(valid)=6.30e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 160: 3.19s to complete
#   error(train)=1.42e-02, acc(train)=9.96e-01, error(valid)=6.32e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 165: 3.83s to complete
#   error(train)=1.37e-02, acc(train)=9.96e-01, error(valid)=6.12e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 170: 3.43s to complete
#   error(train)=1.45e-02, acc(train)=9.96e-01, error(valid)=6.43e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 175: 4.18s to complete
#   error(train)=1.37e-02, acc(train)=9.97e-01, error(valid)=6.27e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 180: 4.55s to complete
#   error(train)=1.36e-02, acc(train)=9.97e-01, error(valid)=6.01e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 185: 3.79s to complete
#   error(train)=1.31e-02, acc(train)=9.97e-01, error(valid)=5.89e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 190: 3.71s to complete
#   error(train)=1.52e-02, acc(train)=9.96e-01, error(valid)=6.29e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 195: 3.17s to complete
#   error(train)=1.27e-02, acc(train)=9.97e-01, error(valid)=6.09e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 200: 3.33s to complete
#   error(train)=1.35e-02, acc(train)=9.96e-01, error(valid)=5.97e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00

# %% [markdown]
# ## Exercise 3: Implementing maxout
#
# [Maxout](http://www.jmlr.org/proceedings/papers/v28/goodfellow13.pdf) can be considered a generalisation of the rectified linear transformation implemented in the previous lab.
#
# For a rectified linear (`Relu`) layer the forward propagation corresponds to
#
# \begin{equation}
#     y^{(b)}_k =
#     \max\left\lbrace 0,\,x^{(b)}_k \right\rbrace
# \end{equation}
#
# i.e. each output corresponds to an pairwise maximum of a constant (0) and the input.
#
# Instead of taking the maximum of the input and a constant, we could instead consider taking the maximum over sets of inputs of a fixed size $s$.
#
# \begin{equation}
#     y^{(b)}_k =
#     \max\left\lbrace x^{(b)}_{(k-1)s + 1},\, x^{(b)}_{(k-1)s + 2},\, \dots ,\, x^{(b)}_{ks} \right\rbrace
# \end{equation}
#
# If these inputs $x^{(b)}_d$ are themselves the outputs of an affine layer, then this corresponds to taking the maximum of a series of affine functions of the previous layer outputs. Like a rectified linear layer this leads to piecewise linear input-output relationships (which have well-behaved gradients which do not suffer from the saturation problems of logistic sigmoid / hyperbolic tangent transformations) but unlike the rectified linear case we do not end force a portion of the outputs to be zero.
#
# Experimentally this form of transformation has been found to give good performance, with the name *maxout* chosen because the *out*put is the *max*imum of a set of inputs. Maxout is also commonly used with dropout layers however note they are not directly related - maxout defines a deterministic non-linear transformation which can help improve the representational capacity and trainability of models; dropout defines a stochastic transformation which is mainly aimed at regularising a model to reduce overfitting.
#
# Using layers which take the maximum of fixed sized sets of inputs is also a common technique in models with convolutional layers which we will cover later in the course, with here the layer commonly being termed a *max-pooling* layer (with there being natural generalisation to other choices of reduction functions over pools such as the mean). We will adopt this terminology here for a layer implementing the transformation described above and we will be able to reuse our code implementing this maximum operation when experimenting with convolutional models.
#
# The partial derivatives of this max-pooling transformation are sparse (lots of values are zero), with only the partial derivative of the output of a pool with respect to the maximum input in the pool non-zero. This can be expressed as
#
# \begin{equation}
#     \frac{\partial y^{(b)}_k}{\partial x^{(b)}_d} =
#     \begin{cases}
#       1 & \quad (k-1)s + 1 \leq d  \leq ks \quad\textrm{and} &x^{(b)}_d = \max\left\lbrace x^{(b)}_{(k-1)s + 1},\, x^{(b)}_{(k-1)s + 2},\, \dots ,\, x^{(b)}_{ks} \right\rbrace \\
#       0 & \quad \textrm{otherwise}
#     \end{cases}.
# \end{equation}
#
# Using these definitions implement the `fprop` and `bprop` methods of the skeleton `MaxPoolingLayer` class below.
#
# Some hints
#
#   * One way of organising the inputs into non-overlapping pools is using the `numpy.reshape` function.
#   * The `numpy.max` function has an `axis` argument which allows you specify the axis (dimension) of the input array to take the maximum over.
#   * It may help to construct a binary mask corresponding to the definitions of the partial derivatives above to allow you to implement the `bprop` method.
#   * As with the `DropoutLayer` it is fine to temporarily store values calculated in the `fprop` method as attributes of the object (e.g. `self.val = val`) to use in the `bprop` method (although you don't necessarily need to do this).

# %%
from mlp.layers import Layer

class MaxPoolingLayer(Layer):
    
    def __init__(self, pool_size=2):
        """Construct a new max-pooling layer.
        
        Args:
            pool_size: Positive integer specifying size of pools over
               which to take maximum value. The outputs of the layer
               feeding in to this layer must have a dimension which
               is a multiple of this pool size such that the outputs
               can be split in to pools with no dimensions left over.
        """
        assert pool_size > 0
        self.pool_size = pool_size
    
    def fprop(self, inputs):
        """Forward propagates activations through the layer transformation.
        
        This corresponds to taking the maximum over non-overlapping pools of
        inputs of a fixed size `pool_size`.

        Args:
            inputs: Array of layer inputs of shape (batch_size, input_dim).

        Returns:
            outputs: Array of layer outputs of shape (batch_size, output_dim).
        """
        assert inputs.shape[-1] % self.pool_size == 0, (
            'Last dimension of inputs must be multiple of pool size')
        
        return inputs.reshape(inputs.shape[0], inputs.shape[1] / self.pool_size, self.pool_size).max(-1)

    def bprop(self, inputs, outputs, grads_wrt_outputs):
        """Back propagates gradients through a layer.

        Given gradients with respect to the outputs of the layer calculates the
        gradients with respect to the layer inputs.

        Args:
            inputs: Array of layer inputs of shape (batch_size, input_dim).
            outputs: Array of layer outputs calculated in forward pass of
                shape (batch_size, output_dim).
            grads_wrt_outputs: Array of gradients with respect to the layer
                outputs of shape (batch_size, output_dim).

        Returns:
            Array of gradients with respect to the layer inputs of shape
            (batch_size, input_dim).
        """
        
        tmp = ( inputs.reshape(inputs.shape[0], inputs.shape[1] / self.pool_size, self.pool_size) == 
        outputs.reshape(outputs.shape[0], outputs.shape[1], 1) ).astype('float')
        tmp_grads = tmp * grads_wrt_outputs.reshape(outputs.shape[0], outputs.shape[1], 1)
        return tmp_grads.reshape(inputs.shape[0], inputs.shape[1])

    def __repr__(self):
        return 'MaxPoolingLayer(pool_size={0})'.format(self.pool_size)

# %% [markdown]
# Test your implementation by running the cell below.

# %%
test_inputs = np.array([[-3, -4, 5, 8], [0, -2, 3, -8], [1, 5, 3, 2]])
test_outputs_1 = np.array([[8], [3], [5]])
test_grads_wrt_outputs_1 = np.array([[10], [5], [-3]])
test_grads_wrt_inputs_1 = np.array([[0, 0, 0, 10], [0, 0, 5, 0], [0, -3, 0, 0]])
test_outputs_2 = np.array([[-3, 8], [0, 3], [5, 3]])
test_grads_wrt_outputs_2 = np.array([[3, -1], [2, 5], [5, 3]])
test_grads_wrt_inputs_2 = np.array([[3, 0, 0, -1], [2, 0, 5, 0], [0, 5, 3, 0]])
layer_1 = MaxPoolingLayer(4)
layer_2 = MaxPoolingLayer(2)
# Check fprop with pool_size = 4
assert np.allclose(layer_1.fprop(test_inputs), test_outputs_1)
# Check bprop with pool_size = 4
print layer_1.bprop(test_inputs, test_outputs_1, test_grads_wrt_outputs_1)
assert np.allclose(
    layer_1.bprop(test_inputs, test_outputs_1, test_grads_wrt_outputs_1),
    test_grads_wrt_inputs_1
)
# Check fprop with pool_size = 2
assert np.allclose(layer_2.fprop(test_inputs), test_outputs_2)
# Check bprop with pool_size = 2
assert np.allclose(
    layer_2.bprop(test_inputs, test_outputs_2, test_grads_wrt_outputs_2),
    test_grads_wrt_inputs_2
)
# Out:
# [[  0.   0.   0.  10.]
#  [  0.   0.   5.   0.]
#  [ -0.  -3.  -0.  -0.]]

# %% [markdown]
# ## Exercise 4: Training with maxout
#
# Use your `MaxPoolingLayer` implementation in a multiple layer models to experiment with how well maxout networks are able to classify MNIST digits. As with the dropout training exercise, code has been provided below as a starting point for setting up the model objects, but again feel free to substitute any components.
#
# If you have time you may wish to experiment with training a model using a combination of maxout and dropout or another regularisation method covered in the last lab notebook.

# %%
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider
from mlp.models import MultipleLayerModel
from mlp.layers import AffineLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.initialisers import GlorotUniformInit, ConstantInit
from mlp.learning_rules import MomentumLearningRule
from mlp.optimisers import Optimiser
import matplotlib.pyplot as plt
# %matplotlib inline

# Seed a random number generator
seed = 31102016 
rng = np.random.RandomState(seed)

# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=50, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=50, rng=rng)

# %%
# Size of pools to take maximum over
pool_size = 2

input_dim, output_dim, hidden_dim = 784, 10, 100

# Use Glorot initialisation scheme for weights and zero biases
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

# Create three affine layer model interleaved with max-pooling layers
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim * pool_size, weights_init, biases_init), 
    MaxPoolingLayer(pool_size),
    AffineLayer(hidden_dim, hidden_dim * pool_size, weights_init, biases_init), 
    MaxPoolingLayer(pool_size),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError()

# Use a momentum learning rule - you could use an adaptive learning rule
# implemented for the coursework here instead
learning_rule = MomentumLearningRule(0.02, 0.9)

# Monitor classification accuracy during training
data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

optimiser = Optimiser(
    model, error, learning_rule, train_data, valid_data, data_monitors)

num_epochs = 100
stats_interval = 5

stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

# Plot the change in the validation and training set error over training.
fig_1 = plt.figure(figsize=(8, 4))
ax_1 = fig_1.add_subplot(111)
for k in ['error(train)', 'error(valid)']:
    ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
              stats[1:, keys[k]], label=k)
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')

# Plot the change in the validation and training set accuracy over training.
fig_2 = plt.figure(figsize=(8, 4))
ax_2 = fig_2.add_subplot(111)
for k in ['acc(train)', 'acc(valid)']:
    ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
              stats[1:, keys[k]], label=k)
ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')
# Out:
# Epoch 0:
#   error(train)=2.45e+00, acc(train)=7.73e-02, error(valid)=2.44e+00, acc(valid)=8.09e-02, params_penalty=0.00e+00
# Epoch 5: 2.29s to complete
#   error(train)=2.67e-02, acc(train)=9.92e-01, error(valid)=8.87e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 10: 2.28s to complete
#   error(train)=8.57e-03, acc(train)=9.97e-01, error(valid)=9.43e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 15: 2.30s to complete
#   error(train)=4.83e-04, acc(train)=1.00e+00, error(valid)=8.21e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 20: 2.32s to complete
#   error(train)=2.45e-04, acc(train)=1.00e+00, error(valid)=8.54e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 25: 2.32s to complete
#   error(train)=1.80e-04, acc(train)=1.00e+00, error(valid)=8.81e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 30: 3.17s to complete
#   error(train)=1.43e-04, acc(train)=1.00e+00, error(valid)=8.99e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 35: 2.33s to complete
#   error(train)=1.19e-04, acc(train)=1.00e+00, error(valid)=9.17e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 40: 2.38s to complete
#   error(train)=1.01e-04, acc(train)=1.00e+00, error(valid)=9.31e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 45: 2.31s to complete
#   error(train)=8.91e-05, acc(train)=1.00e+00, error(valid)=9.48e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 50: 2.33s to complete
#   error(train)=7.84e-05, acc(train)=1.00e+00, error(valid)=9.58e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 55: 2.33s to complete
#   error(train)=7.03e-05, acc(train)=1.00e+00, error(valid)=9.69e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 60: 9.15s to complete
#   error(train)=6.38e-05, acc(train)=1.00e+00, error(valid)=9.78e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 65: 3.35s to complete
#   error(train)=5.82e-05, acc(train)=1.00e+00, error(valid)=9.87e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 70: 2.32s to complete
#   error(train)=5.35e-05, acc(train)=1.00e+00, error(valid)=9.94e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 75: 2.34s to complete
#   error(train)=4.95e-05, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 80: 2.33s to complete
#   error(train)=4.60e-05, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 85: 2.31s to complete
#   error(train)=4.30e-05, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 90: 2.32s to complete
#   error(train)=4.02e-05, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 95: 2.33s to complete
#   error(train)=3.79e-05, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 100: 2.33s to complete
#   error(train)=3.57e-05, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
